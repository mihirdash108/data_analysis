# %%
import requests
res = requests.post('http://metabase.frontrow.co.in/api/session', 
                    headers = {"Content-Type": "application/json"},
                    json =  {"username": "mihir.dash@frontrow.co.in", 
                             "password": "Balio@123"}
                   )
assert res.ok == True
token = res.json()['id']
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): metabase.frontrow.co.in:80
# DEBUG:urllib3.connectionpool:http://metabase.frontrow.co.in:80 "POST /api/session HTTP/1.1" 200 None

# %%
import pandas as pd
res = requests.get('http://metabase.frontrow.co.in/api/card', 
              headers = {'Content-Type': 'application/json',
                        'X-Metabase-Session': token
                        }
            )
res.json()
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): metabase.frontrow.co.in:80
# DEBUG:urllib3.connectionpool:http://metabase.frontrow.co.in:80 "GET /api/card HTTP/1.1" 200 None
# [{'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'created_date',
#     'field_ref': ['field', 'created_date', {'base-type': 'type/Date'}],
#     'name': 'created_date',
#     'base_type': 'type/Date',
#     'effective_type': 'type/Date',
#     'semantic_type': 'type/CreationDate',
#     'fingerprint': {'global': {'distinct-count': 46, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2021-03-23T00:00:00Z',
#        'latest': '2021-05-20T00:00:00Z'}}}},
#    {'display_name': 'Total_Comments',
#     'field_ref': ['field', 'Total_Comments', {'base-type': 'type/BigInteger'}],
#     'name': 'Total_Comments',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 33, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 4.0,
#        'q1': 21.071796769724493,
#        'q3': 60.0,
#        'max': 139.0,
#        'sd': 30.911788161524967,
#        'avg': 41.19565217391305}}}},
#    {'display_name': 'Unique_Users',
#     'field_ref': ['field', 'Unique_Users', {'base-type': 'type/BigInteger'}],
#     'name': 'Unique_Users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 32, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 4.0,
#        'q1': 16.76393202250021,
#        'q3': 38.0,
#        'max': 72.0,
#        'sd': 17.01697078466054,
#        'avg': 29.02173913043478}}}}],
#   'creator': {'email': 'kritwish@frontrow.co.in',
#    'first_name': 'Kritwish',
#    'last_login': '2021-07-29T19:53:00',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 64,
#    'last_name': 'Mondal',
#    'date_joined': '2021-01-30T10:59:46',
#    'common_name': 'Kritwish Mondal'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-1)Comedy Activity Unique Users Daily',
#   'creator_id': 64,
#   'updated_at': '2022-04-09T16:03:06',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'Select \n    date(discussion.created_at) as created_date,\n    Count(comment.user_id) as Total_Comments,\n    Count(Distinct(comment.user_id)) as Unique_Users \nfrom discussion\n    Inner Join comment\n    on discussion.id=comment.parent_post_id\nwhere \n    discussion.community_id=12 and discussion.user_id in (314557,390659) \ngroup by \n    date(discussion.created_at)\nHaving \n    Count(comment.user_id)>1;',
#     'template-tags': {}},
#    'database': 5},
#   'id': 127,
#   'display': 'table',
#   'last-edit-info': {'id': 96,
#    'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_name': 'Dang',
#    'timestamp': '2021-04-24T12:44:48'},
#   'visualization_settings': {'table.pivot_column': 'Total_Comments',
#    'table.cell_column': 'Unique_Users'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-04-17T09:20:37',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'challenge_id',
#     'field_ref': ['field', 'challenge_id', {'base-type': 'type/BigInteger'}],
#     'name': 'challenge_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 624, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1259.0,
#        'q1': 1654.681311994564,
#        'q3': 2656.3038292020096,
#        'max': 3069.0,
#        'sd': 547.5133239720241,
#        'avg': 2116.996794871795}}}},
#    {'display_name': 'content',
#     'field_ref': ['field', 'content', {'base-type': 'type/Text'}],
#     'name': 'content',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 620, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 113.85897435897436}}}},
#    {'display_name': 'Posts',
#     'field_ref': ['field', 'Posts', {'base-type': 'type/BigInteger'}],
#     'name': 'Posts',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 167, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 52.36076204819301,
#        'q3': 100.98827862854448,
#        'max': 315.0,
#        'sd': 45.99937441128345,
#        'avg': 82.17467948717947}}}},
#    {'display_name': 'unique_users',
#     'field_ref': ['field', 'unique_users', {'base-type': 'type/BigInteger'}],
#     'name': 'unique_users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 98, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 36.004214658208255,
#        'q3': 60.4634970287138,
#        'max': 143.0,
#        'sd': 20.309758684087985,
#        'avg': 49.24679487179487}}}}],
#   'creator': {'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_login': '2021-07-16T15:36:28',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 96,
#    'last_name': 'Dang',
#    'date_joined': '2021-03-20T15:18:49',
#    'common_name': 'Himanshu Dang'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-2)Posts on Challenges',
#   'creator_id': 96,
#   'updated_at': '2022-04-26T16:03:17',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'Select \n    challenge_id,\n    challenge.content,\n    Count(discussion.user_id)as Posts,\n    Count(Distinct(discussion.user_id)) as unique_users \nfrom \n    discussion\n    Inner Join challenge\n    on discussion.challenge_id=challenge.id\nWhere \n    discussion.community_id=12 and discussion.challenge_id>=1259\ngroup by \n    challenge_id\nOrder by \n    challenge_id',
#     'template-tags': {}},
#    'database': 5},
#   'id': 98,
#   'display': 'table',
#   'last-edit-info': {'id': 113,
#    'email': 'yogesh.ramchandani@frontrow.co.in',
#    'first_name': 'Yogesh',
#    'last_name': 'Ramchandani',
#    'timestamp': '2021-05-16T07:29:43'},
#   'visualization_settings': {'table.pivot_column': 'Comments',
#    'table.cell_column': 'challenge_id'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-03-30T20:04:59',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'id',
#     'field_ref': ['field', 'id', {'base-type': 'type/BigInteger'}],
#     'name': 'id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': 'type/PK',
#     'fingerprint': None},
#    {'display_name': 'content',
#     'field_ref': ['field', 'content', {'base-type': 'type/Text'}],
#     'name': 'content',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 44, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 147.2826086956522}}}},
#    {'display_name': 'created_at',
#     'field_ref': ['field',
#      'created_at',
#      {'base-type': 'type/DateTimeWithLocalTZ'}],
#     'name': 'created_at',
#     'base_type': 'type/DateTimeWithLocalTZ',
#     'effective_type': 'type/DateTimeWithLocalTZ',
#     'semantic_type': 'type/CreationTimestamp',
#     'fingerprint': {'global': {'distinct-count': 46, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2021-03-23T20:04:34Z',
#        'latest': '2021-05-20T15:45:54Z'}}}},
#    {'display_name': 'Total_Comments',
#     'field_ref': ['field', 'Total_Comments', {'base-type': 'type/BigInteger'}],
#     'name': 'Total_Comments',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 35, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 19.0,
#        'q3': 56.0,
#        'max': 99.0,
#        'sd': 24.442587764358287,
#        'avg': 36.06521739130435}}}},
#    {'display_name': 'Unique_Users',
#     'field_ref': ['field', 'Unique_Users', {'base-type': 'type/BigInteger'}],
#     'name': 'Unique_Users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 33, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 16.0,
#        'q3': 36.0,
#        'max': 54.0,
#        'sd': 14.203762174275576,
#        'avg': 26.17391304347826}}}}],
#   'creator': {'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_login': '2021-07-16T15:36:28',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 96,
#    'last_name': 'Dang',
#    'date_joined': '2021-03-20T15:18:49',
#    'common_name': 'Himanshu Dang'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-3)Comments on activities Comedy',
#   'creator_id': 96,
#   'updated_at': '2022-03-25T12:33:05',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': "Select \n    discussion.id,\n    discussion.content,\n    discussion.created_at,\n    Count(comment.user_id) as Total_Comments,\n    Count(Distinct(comment.user_id)) as Unique_Users \nfrom \n    discussion\n    Inner Join comment\n    on discussion.id=comment.parent_post_id\nwhere \n    discussion.community_id=12 and \n    discussion.updated_by in ('Himanshu Dang','Yogesh Ramchandani') and \n    discussion.user_id in (314557,390659)\ngroup by \n    discussion.id\norder by \n    discussion.id;",
#     'template-tags': {}},
#    'database': 5},
#   'id': 117,
#   'display': 'table',
#   'last-edit-info': {'id': 64,
#    'email': 'kritwish@frontrow.co.in',
#    'first_name': 'Kritwish',
#    'last_name': 'Mondal',
#    'timestamp': '2021-04-27T04:55:19'},
#   'visualization_settings': {'table.pivot_column': 'id',
#    'table.cell_column': 'Total_Comments'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-04-07T07:36:53',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'Date(created_at)',
#     'field_ref': ['field', 'Date(created_at)', {'base-type': 'type/Date'}],
#     'name': 'Date(created_at)',
#     'base_type': 'type/Date',
#     'effective_type': 'type/Date',
#     'semantic_type': 'type/CreationDate',
#     'fingerprint': {'global': {'distinct-count': 353, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2021-03-23T00:00:00Z',
#        'latest': '2022-03-10T00:00:00Z'}}}},
#    {'display_name': 'Total_Comments',
#     'field_ref': ['field', 'Total_Comments', {'base-type': 'type/BigInteger'}],
#     'name': 'Total_Comments',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 208, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 76.82130624166867,
#        'q3': 187.69339860386268,
#        'max': 445.0,
#        'sd': 87.44789169809467,
#        'avg': 140.80169971671387}}}},
#    {'display_name': 'Unique_Users',
#     'field_ref': ['field', 'Unique_Users', {'base-type': 'type/BigInteger'}],
#     'name': 'Unique_Users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 95, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 38.8667414793784,
#        'q3': 67.40028910200418,
#        'max': 121.0,
#        'sd': 23.222029971588682,
#        'avg': 52.27762039660057}}}}],
#   'creator': {'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_login': '2021-07-16T15:36:28',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 96,
#    'last_name': 'Dang',
#    'date_joined': '2021-03-20T15:18:49',
#    'common_name': 'Himanshu Dang'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-4) Comedy Challenge Unique Users Daily',
#   'creator_id': 96,
#   'updated_at': '2022-03-10T11:36:38',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'Select \n  Date(created_at),\n  Count(user_id) as Total_Comments,\n  Count(Distinct(user_id)) as Unique_Users \nfrom \n    discussion\nWhere \n    community_id=12 and challenge_id>=1259\nGroup by\n    Date(created_at)\nOrder by\n    Date(created_at)\n',
#     'template-tags': {}},
#    'database': 5},
#   'id': 128,
#   'display': 'table',
#   'last-edit-info': {'id': 96,
#    'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_name': 'Dang',
#    'timestamp': '2021-04-18T07:54:42'},
#   'visualization_settings': {'table.pivot_column': 'Unique_Users',
#    'table.cell_column': 'Total_Comments'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-04-18T07:54:42',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'base_type': 'type/BigInteger',
#     'display_name': 'week(created_at)',
#     'name': 'week(created_at)',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 49, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 0.0,
#        'q1': 15.75,
#        'q3': 40.25,
#        'max': 52.0,
#        'sd': 15.288273039065164,
#        'avg': 27.346938775510203}}}},
#    {'base_type': 'type/BigInteger',
#     'display_name': 'Total_Comments',
#     'name': 'Total_Comments',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 48, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 21.0,
#        'q1': 556.25,
#        'q3': 1291.25,
#        'max': 2284.0,
#        'sd': 557.3629578979345,
#        'avg': 994.6938775510204}}}},
#    {'base_type': 'type/BigInteger',
#     'display_name': 'Unique_Users',
#     'name': 'Unique_Users',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 43, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 17.0,
#        'q1': 144.32576538582524,
#        'q3': 237.25,
#        'max': 333.0,
#        'sd': 72.2556814610544,
#        'avg': 189.69387755102042}}}}],
#   'creator': {'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_login': '2021-07-16T15:36:28',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 96,
#    'last_name': 'Dang',
#    'date_joined': '2021-03-20T15:18:49',
#    'common_name': 'Himanshu Dang'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-5) Weekly unique users- Challenge',
#   'creator_id': 96,
#   'updated_at': '2022-02-15T17:34:00',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'Select \n  week(created_at),\n  Count(user_id) as Total_Comments,\n  Count(Distinct(user_id)) as Unique_Users \nfrom \n    discussion\nWhere \n    community_id=12 and challenge_id>=1259\nGroup by\n    week(created_at)\nOrder by\n    week(created_at)\n',
#     'template-tags': {}},
#    'database': 5},
#   'id': 130,
#   'display': 'table',
#   'last-edit-info': {'id': 96,
#    'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_name': 'Dang',
#    'timestamp': '2021-04-23T17:27:19'},
#   'visualization_settings': {'table.pivot_column': 'week(created_at)',
#    'table.cell_column': 'Total_Comments'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-04-23T17:27:02',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'created_date',
#     'field_ref': ['field', 'created_date', {'base-type': 'type/BigInteger'}],
#     'name': 'created_date',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 8, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 12.0,
#        'q1': 13.5,
#        'q3': 17.5,
#        'max': 20.0,
#        'sd': 2.669269563007828,
#        'avg': 15.625}}}},
#    {'display_name': 'Total_Comments',
#     'field_ref': ['field', 'Total_Comments', {'base-type': 'type/BigInteger'}],
#     'name': 'Total_Comments',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 8, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 21.0,
#        'q1': 138.0,
#        'q3': 337.5,
#        'max': 394.0,
#        'sd': 128.64506819706915,
#        'avg': 236.875}}}},
#    {'display_name': 'Unique_Users',
#     'field_ref': ['field', 'Unique_Users', {'base-type': 'type/BigInteger'}],
#     'name': 'Unique_Users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 8, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 18.0,
#        'q1': 77.0,
#        'q3': 155.0,
#        'max': 163.0,
#        'sd': 50.437372764930686,
#        'avg': 108.75}}}}],
#   'creator': {'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_login': '2021-07-16T15:36:28',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 96,
#    'last_name': 'Dang',
#    'date_joined': '2021-03-20T15:18:49',
#    'common_name': 'Himanshu Dang'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-6) Comments on challenges(Weekly)',
#   'creator_id': 96,
#   'updated_at': '2022-04-14T10:33:01',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'Select \n    week(discussion.created_at) as created_date,\n    Count(comment.user_id) as Total_Comments,\n    Count(Distinct(comment.user_id)) as Unique_Users \nfrom discussion\n    Inner Join comment\n    on discussion.id=comment.parent_post_id\nwhere \n    discussion.community_id=12 and discussion.user_id in (314557,390659) \ngroup by \n    week(discussion.created_at)\nHaving \n    Count(comment.user_id)>1;',
#     'template-tags': {}},
#    'database': 5},
#   'id': 140,
#   'display': 'table',
#   'last-edit-info': {'id': 96,
#    'email': 'himanshu.dang@frontrow.co.in',
#    'first_name': 'Himanshu',
#    'last_name': 'Dang',
#    'timestamp': '2021-04-26T07:23:39'},
#   'visualization_settings': {'table.pivot_column': 'created_date',
#    'table.cell_column': 'Total_Comments'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-04-26T07:23:39',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'id',
#     'field_ref': ['field', 'id', {'base-type': 'type/BigInteger'}],
#     'name': 'id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': 'type/PK',
#     'fingerprint': None},
#    {'display_name': 'created_at',
#     'field_ref': ['field',
#      'created_at',
#      {'base-type': 'type/DateTimeWithLocalTZ'}],
#     'name': 'created_at',
#     'base_type': 'type/DateTimeWithLocalTZ',
#     'effective_type': 'type/DateTimeWithLocalTZ',
#     'semantic_type': 'type/CreationTimestamp',
#     'fingerprint': {'global': {'distinct-count': 27, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2021-04-28T07:58:15Z',
#        'latest': '2021-05-22T15:36:29Z'}}}},
#    {'display_name': 'Total_Response',
#     'field_ref': ['field', 'Total_Response', {'base-type': 'type/BigInteger'}],
#     'name': 'Total_Response',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 26, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 264.0,
#        'q1': 303.75,
#        'q3': 407.0,
#        'max': 564.0,
#        'sd': 77.74604358710026,
#        'avg': 362.7037037037037}}}},
#    {'display_name': 'Unique_Users',
#     'field_ref': ['field', 'Unique_Users', {'base-type': 'type/BigInteger'}],
#     'name': 'Unique_Users',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 26, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 264.0,
#        'q1': 303.75,
#        'q3': 407.0,
#        'max': 564.0,
#        'sd': 77.74604358710026,
#        'avg': 362.7037037037037}}}}],
#   'creator': {'email': 'yogesh.ramchandani@frontrow.co.in',
#    'first_name': 'Yogesh',
#    'last_login': '2021-06-23T05:44:56',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 113,
#    'last_name': 'Ramchandani',
#    'date_joined': '2021-04-23T10:53:21',
#    'common_name': 'Yogesh Ramchandani'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': '(H-8) Comedy_Quiz_Response',
#   'creator_id': 113,
#   'updated_at': '2022-04-21T15:44:27',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': "Select \n    poll.id,\n    poll.created_at,\n    Count(poll_participation.user_id) as Total_Response,\n    Count(Distinct(poll_participation.user_id)) as Unique_Users \nfrom \n    poll_participation\n     Inner Join poll\n    on poll.id=poll_participation.poll_id\nwhere \n     poll.community_id=12 and \n    poll.updated_by in ('Himanshu Dang','Yogesh Ramchandani','Samil') and \n     poll.user_id in (314557,390659,17404)\ngroup by \n   poll.id\norder by \n   poll.id;",
#     'template-tags': {}},
#    'database': 5},
#   'id': 145,
#   'display': 'table',
#   'last-edit-info': {'id': 113,
#    'email': 'yogesh.ramchandani@frontrow.co.in',
#    'first_name': 'Yogesh',
#    'last_name': 'Ramchandani',
#    'timestamp': '2021-05-16T07:00:57'},
#   'visualization_settings': {'table.pivot_column': 'Total_Response',
#    'table.cell_column': 'id'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-05-04T05:48:56',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'order_at',
#     'semantic_type': None,
#     'field_ref': ['field',
#      'order_at',
#      {'base-type': 'type/DateTime', 'temporal-unit': 'default'}],
#     'name': 'order_at',
#     'base_type': 'type/DateTime',
#     'effective_type': 'type/DateTime',
#     'unit': 'default',
#     'fingerprint': {'global': {'distinct-count': 1623, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2022-03-05T19:34:16Z',
#        'latest': '2022-03-07T04:34:12Z'}}}},
#    {'display_name': 'user_id',
#     'semantic_type': None,
#     'field_ref': ['field', 'user_id', {'base-type': 'type/BigInteger'}],
#     'name': 'user_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'fingerprint': {'global': {'distinct-count': 1646, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1720.0,
#        'q1': 1763827.9473684211,
#        'q3': 1807326.8887186772,
#        'max': 1809557.0,
#        'sd': 416513.03575081215,
#        'avg': 1617679.756}}}},
#    {'display_name': 'course_id',
#     'semantic_type': None,
#     'field_ref': ['field', 'course_id', {'base-type': 'type/BigInteger'}],
#     'name': 'course_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'fingerprint': {'global': {'distinct-count': 13, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 231.0,
#        'q1': 232.01813359880222,
#        'q3': 544.0064730122645,
#        'max': 549.0,
#        'sd': 156.28744928224907,
#        'avg': 393.5555}}}},
#    {'display_name': 'course_batch_id',
#     'semantic_type': None,
#     'field_ref': ['field',
#      'course_batch_id',
#      {'base-type': 'type/BigInteger'}],
#     'name': 'course_batch_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'fingerprint': {'global': {'distinct-count': 28, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 4937.0,
#        'q1': 4987.4657978230525,
#        'q3': 5133.840417285426,
#        'max': 5416.0,
#        'sd': 83.39109097965677,
#        'avg': 5061.0385}}}},
#    {'display_name': 'course_name',
#     'semantic_type': None,
#     'field_ref': ['field', 'course_name', {'base-type': 'type/Text'}],
#     'name': 'course_name',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'fingerprint': {'global': {'distinct-count': 10, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 29.7155}}}},
#    {'display_name': 'contact',
#     'semantic_type': None,
#     'field_ref': ['field', 'contact', {'base-type': 'type/Text'}],
#     'name': 'contact',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'fingerprint': {'global': {'distinct-count': 1646, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 9.999}}}},
#    {'display_name': 'Question 270 → courseBatchName',
#     'field_ref': ['field',
#      'courseBatchName',
#      {'base-type': 'type/Text', 'join-alias': 'Question 270'}],
#     'name': 'courseBatchName',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 6, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 29.2795}}}},
#    {'display_name': 'Question 270 → batchStartDate',
#     'field_ref': ['field',
#      'batchStartDate',
#      {'base-type': 'type/DateTime',
#       'join-alias': 'Question 270',
#       'temporal-unit': 'default'}],
#     'name': 'batchStartDate',
#     'base_type': 'type/DateTime',
#     'effective_type': 'type/DateTime',
#     'unit': 'default',
#     'semantic_type': 'type/CreationTimestamp',
#     'fingerprint': {'global': {'distinct-count': 6, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2021-11-01T18:00:00Z',
#        'latest': '2021-11-07T18:00:00Z'}}}},
#    {'display_name': 'Question 270 → userCount',
#     'field_ref': ['field',
#      'userCount',
#      {'base-type': 'type/BigInteger', 'join-alias': 'Question 270'}],
#     'name': 'userCount',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': 'type/Quantity',
#     'fingerprint': {'global': {'distinct-count': 5, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 336.0,
#        'q1': 341.377133467687,
#        'q3': 349.6010503551181,
#        'max': 353.0,
#        'sd': 5.362739550616259,
#        'avg': 345.398}}}}],
#   'creator': {'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_login': '2022-05-13T14:24:53',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 437,
#    'last_name': 'Dash',
#    'date_joined': '2021-11-01T02:43:45',
#    'common_name': 'Mihir Dash'},
#   'database_id': 3,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'query',
#   'name': '299+ gaming+dance',
#   'creator_id': 437,
#   'updated_at': '2022-03-08T05:41:21',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'query',
#    'query': {'source-table': 'card__238',
#     'joins': [{'fields': [['field',
#         'courseBatchName',
#         {'base-type': 'type/Text', 'join-alias': 'Question 270'}],
#        ['field',
#         'batchStartDate',
#         {'base-type': 'type/DateTime', 'join-alias': 'Question 270'}],
#        ['field',
#         'userCount',
#         {'base-type': 'type/BigInteger', 'join-alias': 'Question 270'}]],
#       'source-table': 'card__270',
#       'condition': ['=',
#        ['field', 'course_batch_id', {'base-type': 'type/BigInteger'}],
#        ['field',
#         'courseBatchId',
#         {'base-type': 'type/BigInteger', 'join-alias': 'Question 270'}]],
#       'alias': 'Question 270'}],
#     'filter': ['and',
#      ['=',
#       ['field', 'course_id', {'base-type': 'type/BigInteger'}],
#       231,
#       232,
#       233,
#       234,
#       337,
#       320],
#      ['between',
#       ['field',
#        'batchStartDate',
#        {'base-type': 'type/DateTime', 'join-alias': 'Question 270'}],
#       '2021-11-01',
#       '2021-11-30']],
#     'fields': [['field', 'order_at', {'base-type': 'type/DateTime'}],
#      ['field', 'user_id', {'base-type': 'type/BigInteger'}],
#      ['field', 'course_id', {'base-type': 'type/BigInteger'}],
#      ['field', 'course_batch_id', {'base-type': 'type/BigInteger'}],
#      ['field', 'course_name', {'base-type': 'type/Text'}],
#      ['field', 'contact', {'base-type': 'type/Text'}]]},
#    'database': 3},
#   'id': 325,
#   'display': 'table',
#   'last-edit-info': {'id': 437,
#    'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_name': 'Dash',
#    'timestamp': '2021-11-21T13:13:35'},
#   'visualization_settings': {'graph.dimensions': ['course_id'],
#    'stackable.stack_type': 'stacked',
#    'table.columns': [{'name': 'order_at',
#      'fieldRef': ['field-literal', 'order_at', 'type/DateTime'],
#      'enabled': True},
#     {'name': 'user_id',
#      'fieldRef': ['field-literal', 'user_id', 'type/BigInteger'],
#      'enabled': True},
#     {'name': 'course_id',
#      'fieldRef': ['field-literal', 'course_id', 'type/BigInteger'],
#      'enabled': True},
#     {'name': 'course_batch_id',
#      'fieldRef': ['field-literal', 'course_batch_id', 'type/BigInteger'],
#      'enabled': True},
#     {'name': 'course_name',
#      'fieldRef': ['field-literal', 'course_name', 'type/Text'],
#      'enabled': True},
#     {'name': 'instructor_name',
#      'fieldRef': ['field-literal', 'instructor_name', 'type/Text'],
#      'enabled': False},
#     {'name': 'contact',
#      'fieldRef': ['field-literal', 'contact', 'type/Text'],
#      'enabled': True},
#     {'name': 'courseBatchName',
#      'fieldRef': ['field',
#       'courseBatchName',
#       {'base-type': 'type/Text', 'join-alias': 'Question 270'}],
#      'enabled': True},
#     {'name': 'batchStartDate',
#      'fieldRef': ['field',
#       'batchStartDate',
#       {'base-type': 'type/DateTime', 'join-alias': 'Question 270'}],
#      'enabled': True},
#     {'name': 'userCount',
#      'fieldRef': ['field',
#       'userCount',
#       {'base-type': 'type/BigInteger', 'join-alias': 'Question 270'}],
#      'enabled': True}],
#    'table.pivot_column': 'courseBatchName',
#    'table.cell_column': 'user_id',
#    'graph.metrics': ['userCount']},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-11-21T13:13:35',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'user_id',
#     'field_ref': ['field', 'user_id', {'base-type': 'type/Text'}],
#     'name': 'user_id',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1874, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 5.9515}}}},
#    {'display_name': 'community_id',
#     'field_ref': ['field', 'community_id', {'base-type': 'type/BigInteger'}],
#     'name': 'community_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 3, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 5.0,
#        'q1': 5.0,
#        'q3': 8.783445619276346,
#        'max': 9.0,
#        'sd': 1.8944631153040756,
#        'avg': 6.798}}}},
#    {'display_name': 'community_name',
#     'field_ref': ['field', 'community_name', {'base-type': 'type/Text'}],
#     'name': 'community_name',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 3, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 4.209}}}},
#    {'display_name': 'total_question_count',
#     'field_ref': ['field',
#      'total_question_count',
#      {'base-type': 'type/BigInteger'}],
#     'name': 'total_question_count',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': 'type/Quantity',
#     'fingerprint': {'global': {'distinct-count': 8, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 6.0,
#        'q1': 7.9411046830467935,
#        'q3': 13.079870903843648,
#        'max': 20.0,
#        'sd': 2.720128544692295,
#        'avg': 10.4755}}}},
#    {'display_name': 'response_count',
#     'field_ref': ['field', 'response_count', {'base-type': 'type/BigInteger'}],
#     'name': 'response_count',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': 'type/Quantity',
#     'fingerprint': {'global': {'distinct-count': 7, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 0.0,
#        'q1': 0.6345839901320407,
#        'q3': 2.4993518578745952,
#        'max': 6.0,
#        'sd': 1.1077023527334071,
#        'avg': 1.603}}}},
#    {'display_name': 'percentage_responses',
#     'field_ref': ['field',
#      'percentage_responses',
#      {'base-type': 'type/Decimal'}],
#     'name': 'percentage_responses',
#     'base_type': 'type/Decimal',
#     'effective_type': 'type/Decimal',
#     'semantic_type': 'type/Share',
#     'fingerprint': {'global': {'distinct-count': 22, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 0.0,
#        'q1': 6.773594543346721,
#        'q3': 19.601910005262646,
#        'max': 75.0,
#        'sd': 14.30081748761594,
#        'avg': 16.898137150000004}}}}],
#   'creator': {'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_login': '2022-05-04T17:28:33',
#    'is_qbnewb': False,
#    'is_superuser': True,
#    'id': 1,
#    'last_name': 'Sharma',
#    'date_joined': '2020-06-01T21:10:37',
#    'common_name': 'Shubhadit Sharma'},
#   'database_id': 8,
#   'enable_embedding': False,
#   'collection_id': 97,
#   'query_type': 'native',
#   'name': 'AB Experiment - Community Onboarding Questions',
#   'creator_id': 1,
#   'updated_at': '2022-05-09T05:40:32',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'SELECT\n  ab.user_bucket_mapping.splitting_parameter_value AS user_id,\n  community.user_community.community_id AS community_id,\n  community.community.name AS community_name,\n  COUNT(community.onboarding_question.id) AS total_question_count,\n  COUNT(DISTINCT(community.onboarding_user_response.question_id)) AS response_count,\n  (COUNT(DISTINCT(community.onboarding_user_response.question_id)) / COUNT(community.onboarding_question.id) * 100) AS percentage_responses\nFROM\n  ab.user_bucket_mapping\n  INNER JOIN\n    community.user_community\n    ON community.user_community.user_id = ab.user_bucket_mapping.splitting_parameter_value\n  INNER JOIN\n    community.community\n    ON community.community.id = community.user_community.community_id\n  INNER JOIN\n    community.onboarding_question\n    ON community.onboarding_question.community_id = community.user_community.community_id\n  LEFT JOIN\n    community.onboarding_user_response\n    ON community.onboarding_user_response.question_id = community.onboarding_question.id\n    AND community.onboarding_user_response.user_id = ab.user_bucket_mapping.splitting_parameter_value\nWHERE\n  ab.user_bucket_mapping.experiment_id = 1\n  AND ab.user_bucket_mapping.bucket_id = 2\nGROUP BY\n  ab.user_bucket_mapping.splitting_parameter_value,\n  community.user_community.community_id\nORDER BY\n  community.user_community.community_id,\n  ab.user_bucket_mapping.splitting_parameter_value;',
#     'template-tags': {}},
#    'database': 8},
#   'id': 85,
#   'display': 'table',
#   'last-edit-info': {'id': 1,
#    'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_name': 'Sharma',
#    'timestamp': '2021-03-23T08:37:09'},
#   'visualization_settings': {'table.pivot_column': 'community_id',
#    'table.cell_column': 'total_question_count'},
#   'collection': {'authority_level': None,
#    'description': None,
#    'archived': False,
#    'slug': 'ab_analytics',
#    'color': '#509EE3',
#    'name': 'AB Analytics',
#    'personal_owner_id': None,
#    'id': 97,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-03-19T10:21:12',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'base_type': 'type/Text',
#     'display_name': 'bucket',
#     'name': 'bucket',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'average-length': 5.5}}}},
#    {'base_type': 'type/Text',
#     'display_name': 'platform',
#     'name': 'platform',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 5, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'average-length': 4.8}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'orders',
#     'name': 'orders',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 10, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 49.0,
#        'q3': 926.0,
#        'max': 1004.0,
#        'sd': 431.31788998628633,
#        'avg': 459.7}}}},
#    {'base_type': 'type/BigInteger',
#     'display_name': 'attempts',
#     'name': 'attempts',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 10, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 188.0,
#        'q3': 1350.0,
#        'max': 1477.0,
#        'sd': 624.7792854725224,
#        'avg': 670.4}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'conversion',
#     'name': 'conversion',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 9, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 26.0638,
#        'q1': 62.6947,
#        'q3': 92.9348,
#        'max': 100.0,
#        'sd': 25.685506739380827,
#        'avg': 72.05339}}}}],
#   'creator': {'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_login': '2022-05-04T17:28:33',
#    'is_qbnewb': False,
#    'is_superuser': True,
#    'id': 1,
#    'last_name': 'Sharma',
#    'date_joined': '2020-06-01T21:10:37',
#    'common_name': 'Shubhadit Sharma'},
#   'database_id': 8,
#   'enable_embedding': False,
#   'collection_id': 97,
#   'query_type': 'native',
#   'name': 'AB Experiment - Order Screen Redesign',
#   'creator_id': 1,
#   'updated_at': '2021-12-22T19:03:44',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': "SELECT\n  CASE\n    WHEN\n      ab.user_bucket_mapping.bucket_id = 3\n    THEN\n      'CONTROL'\n    WHEN\n      ab.user_bucket_mapping.bucket_id = 4\n    THEN\n      'TEST'\n  END\n  AS bucket,\n  order.frontrow_order.platform AS platform,\n  SUM(IF(order.frontrow_order.order_status = 'COMPLETED', 1, 0)) AS orders,\n  COUNT(DISTINCT order.frontrow_order.user_id) AS attempts,\n  (\n    SUM(IF(order.frontrow_order.order_status = 'COMPLETED', 1, 0)) / COUNT(DISTINCT order.frontrow_order.user_id)\n  )\n  * 100 AS conversion\nFROM\n  ab.user_bucket_mapping\n  INNER JOIN\n    order.frontrow_order\n    ON order.frontrow_order.user_id = ab.user_bucket_mapping.splitting_parameter_value\nWHERE\n  experiment_id = 2\n  AND order.frontrow_order.created_at > '2021-03-17 18:30:00'\nGROUP BY\n  ab.user_bucket_mapping.bucket_id, order.frontrow_order.platform;",
#     'template-tags': {}},
#    'database': 8},
#   'id': 80,
#   'display': 'table',
#   'last-edit-info': {'id': 1,
#    'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_name': 'Sharma',
#    'timestamp': '2021-03-18T06:50:58'},
#   'visualization_settings': {'table.pivot_column': 'bucket',
#    'table.cell_column': 'orders'},
#   'collection': {'authority_level': None,
#    'description': None,
#    'archived': False,
#    'slug': 'ab_analytics',
#    'color': '#509EE3',
#    'name': 'AB Analytics',
#    'personal_owner_id': None,
#    'id': 97,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-03-18T06:16:28',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'base_type': 'type/Text',
#     'display_name': 'bucket',
#     'name': 'bucket',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'average-length': 5.5}}}},
#    {'base_type': 'type/BigInteger',
#     'display_name': 'user_count',
#     'name': 'user_count',
#     'special_type': 'type/Quantity',
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 59895.0,
#        'q1': 59895.0,
#        'q3': 90715.0,
#        'max': 90715.0,
#        'sd': 21793.030996169393,
#        'avg': 75305.0}}}},
#    {'base_type': 'type/BigInteger',
#     'display_name': 'order_attempt_count',
#     'name': 'order_attempt_count',
#     'special_type': 'type/Quantity',
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 3715.0,
#        'q1': 3715.0,
#        'q3': 4556.0,
#        'max': 4556.0,
#        'sd': 594.6768029778865,
#        'avg': 4135.5}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'user_attempt_conversion',
#     'name': 'user_attempt_conversion',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 5.0223,
#        'q1': 5.0223,
#        'q3': 6.2025,
#        'max': 6.2025,
#        'sd': 0.8345274231563629,
#        'avg': 5.6124}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'order_count',
#     'name': 'order_count',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 2159.0,
#        'q1': 2159.0,
#        'q3': 2367.0,
#        'max': 2367.0,
#        'sd': 147.07821048680188,
#        'avg': 2263.0}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'attempt_order_conversion',
#     'name': 'attempt_order_conversion',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 51.9535,
#        'q1': 51.9535,
#        'q3': 58.1157,
#        'max': 58.1157,
#        'sd': 4.357333407027742,
#        'avg': 55.0346}}}},
#    {'base_type': 'type/Decimal',
#     'display_name': 'overall_order_conversion',
#     'name': 'overall_order_conversion',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 2, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 2.6093,
#        'q1': 2.6093,
#        'q3': 3.6046,
#        'max': 3.6046,
#        'sd': 0.7037833793149706,
#        'avg': 3.1069500000000003}}}}],
#   'creator': {'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_login': '2022-05-04T17:28:33',
#    'is_qbnewb': False,
#    'is_superuser': True,
#    'id': 1,
#    'last_name': 'Sharma',
#    'date_joined': '2020-06-01T21:10:37',
#    'common_name': 'Shubhadit Sharma'},
#   'database_id': 8,
#   'enable_embedding': False,
#   'collection_id': 97,
#   'query_type': 'native',
#   'name': 'AB Experiment - Unified UX Order Conversion',
#   'creator_id': 1,
#   'updated_at': '2021-12-02T05:43:24',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': "SELECT\n  CASE\n    WHEN\n      ab.user_bucket_mapping.bucket_id = 5\n    THEN\n      'CONTROL'\n    WHEN\n      ab.user_bucket_mapping.bucket_id = 6\n    THEN\n      'TEST'\n  END\n  AS bucket,\n  COUNT(DISTINCT user.user_device.device_id) AS user_count,\n  COUNT(DISTINCT order.frontrow_order.user_id) AS order_attempt_count,\n  (COUNT(DISTINCT order.frontrow_order.user_id) / COUNT(DISTINCT user.user_device.device_id)) * 100 AS user_attempt_conversion,\n  SUM(IF(order.frontrow_order.order_status = 'COMPLETED', 1, 0)) AS order_count,\n  (\n    SUM(IF(order.frontrow_order.order_status = 'COMPLETED', 1, 0)) / COUNT(DISTINCT order.frontrow_order.user_id)\n  )\n  * 100 AS attempt_order_conversion,\n  (SUM(IF(order.frontrow_order.order_status = 'COMPLETED', 1, 0)) / COUNT(DISTINCT user.user_device.device_id)) * 100 AS overall_order_conversion\nFROM\n  ab.user_bucket_mapping\n  LEFT JOIN\n    user.user_device\n    ON user.user_device.advertising_id = ab.user_bucket_mapping.splitting_parameter_value\n  LEFT JOIN\n    order.frontrow_order\n    ON order.frontrow_order.user_id = user.user_device.user_id AND order.frontrow_order.platform in ('ANDROID', 'IOS')\nWHERE\n  experiment_id = 3\n  AND user.user_device.created_at > '2021-06-21 06:00:00'\nGROUP BY\n  ab.user_bucket_mapping.bucket_id;",
#     'template-tags': {}},
#    'database': 8},
#   'id': 186,
#   'display': 'table',
#   'last-edit-info': {'id': 1,
#    'email': 'shubhadit@frontrow.co.in',
#    'first_name': 'Shubhadit',
#    'last_name': 'Sharma',
#    'timestamp': '2021-06-29T05:30:43'},
#   'visualization_settings': {'table.pivot_column': 'bucket',
#    'table.cell_column': 'user_count'},
#   'collection': {'authority_level': None,
#    'description': None,
#    'archived': False,
#    'slug': 'ab_analytics',
#    'color': '#509EE3',
#    'name': 'AB Analytics',
#    'personal_owner_id': None,
#    'id': 97,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-06-21T04:38:51',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'base_type': 'type/Decimal',
#     'display_name': 'avg(t.votes)',
#     'name': 'avg(t.votes)',
#     'special_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 7.6422,
#        'q1': 7.6422,
#        'q3': 7.6422,
#        'max': 7.6422,
#        'sd': None,
#        'avg': 7.6422}}}}],
#   'creator': {'email': 'kritwish@frontrow.co.in',
#    'first_name': 'Kritwish',
#    'last_login': '2021-07-29T19:53:00',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 64,
#    'last_name': 'Mondal',
#    'date_joined': '2021-01-30T10:59:46',
#    'common_name': 'Kritwish Mondal'},
#   'database_id': 5,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': 'Average Likes',
#   'creator_id': 64,
#   'updated_at': '2021-05-08T13:54:46',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
# ...
#    'name': 'Order Reports',
#    'personal_owner_id': None,
#    'id': 109,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-09-20T19:21:29',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': None,
#   'creator': {'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_login': '2022-05-13T14:24:53',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 437,
#    'last_name': 'Dash',
#    'date_joined': '2021-11-01T02:43:45',
#    'common_name': 'Mihir Dash'},
#   'database_id': 4,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'native',
#   'name': 'ws attendance with utm details',
#   'creator_id': 437,
#   'updated_at': '2022-04-05T13:11:37',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'query': 'SELECT\n  user.user.id AS user_id,\n  content.course_batch_content.id AS lesson_id,\n  content.course_batch.id AS batch_id,\n  content.course.id AS course_id,\n  content.course.resource_type AS course_type,\n  IF(MAX(content.user_course_content_attendance.id) IS NOT NULL, \'YES\', \'NO\') AS has_attended,\n  DATE_ADD(batch_data.batch_start_date, INTERVAL \'5:30\' HOUR_MINUTE) AS batch_start_date,\n  DATE_ADD(content.course_batch_content.start_date, INTERVAL \'5:30\' HOUR_MINUTE) AS class_start_time,\n  DATE_ADD(MIN(IF(content.user_course_content_attendance.event_type = \'JOIN\' AND content.user_course_content_attendance.created_at > DATE_SUB(content.course_batch_content.start_date, INTERVAL 15 MINUTE) AND content.user_course_content_attendance.created_at < content.course_batch_content.end_date, content.user_course_content_attendance.created_at, NULL)), INTERVAL \'5:30\' HOUR_MINUTE) AS joined_at,\n  user.user.contact AS contact,\n  user.user.name AS user_name,\n  content.course_batch_content.is_cancelled AS is_cancelled,\n  content.user_lead.metadata ->> " $ .marketingMetadata.utm_medium" AS utm_medium,\n  content.user_lead.metadata ->> " $ .marketingMetadata.utm_source" AS utm_source,\n  content.user_lead.metadata ->> " $ .marketingMetadata.utm_content" AS utm_content,\n  content.user_lead.metadata ->> " $ .marketingMetadata.utm_campaign" AS utm_campaign,\n  content.user_lead.metadata ->> " $ .marketingMetadata.utm_term" AS utm_term,\n  date_add(content.user_lead.metadata ->> " $ .marketingMetadata.timestamp", INTERVAL \'5:30\' HOUR_MINUTE) AS utm_visit_time\nFROM\n  ((SELECT user_id, course_batch_id FROM content.course_batch_user_mapping) UNION (SELECT DISTINCT user_id, course_batch_id FROM content.user_course_content_attendance)) AS user_batch_mapping\n  LEFT JOIN\n    content.course_batch\n    ON content.course_batch.id = user_batch_mapping.course_batch_id\n\n  LEFT JOIN (\n    SELECT \n      content.course_batch.id AS course_batch_id,\n      MIN(content.course_batch_content.start_date) AS batch_start_date\n    FROM\n      content.course_batch\n      INNER JOIN\n        content.course_batch_module\n        ON content.course_batch_module.course_batch_id = content.course_batch.id\n      INNER JOIN\n        content.course_batch_content\n        ON content.course_batch_content.course_batch_module_id = content.course_batch_module.id\n    WHERE\n      content.course_batch.is_deleted = false\n      AND content.course_batch_module.is_active = true\n    GROUP BY\n      content.course_batch.id\n  ) AS batch_data\n  ON batch_data.course_batch_id = content.course_batch.id\n  LEFT JOIN\n    content.course_batch_module\n    ON content.course_batch_module.course_batch_id = content.course_batch.id\n  LEFT JOIN\n    content.course_batch_content\n    ON content.course_batch_content.course_batch_module_id = content.course_batch_module.id\n  LEFT JOIN\n    content.user_course_content_attendance\n    ON content.user_course_content_attendance.user_id = user_batch_mapping.user_id\n    AND content.user_course_content_attendance.content_id = content.course_batch_content.id\n\n  INNER JOIN\n    content.course\n    ON content.course.id = content.course_batch.course_id\n  INNER JOIN\n    user.user\n    ON user.user.id = user_batch_mapping.user_id\n  LEFT JOIN\n    user.user_device\n    ON user.user_device.user_id = user.user.id\n  LEFT JOIN\n    content.user_lead\n    ON content.user_lead.contact = user.user.contact\nWHERE\n  content.course_batch.is_deleted = false\n  AND content.course_batch_module.is_active = true\n  AND content.course_batch_content.start_date <= now()\n  [[AND find_in_set(user.user.id, REPLACE({{user_ids}}, \' \', \'\')) > 0]]\n\nGROUP BY\n  user.user.id,\n  content.course_batch.id,\n  content.course_batch_content.id,\n  content.user_lead.metadata\nORDER BY\n  content.course_batch_content.start_date DESC;',
#     'template-tags': {'user_ids': {'id': 'b75b96f4-bf22-0031-35e8-dd9213cc5a7c',
#       'name': 'user_ids',
#       'display-name': 'User Ids',
#       'type': 'text'}}},
#    'database': 4},
#   'id': 432,
#   'display': 'table',
#   'last-edit-info': {'id': 437,
#    'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_name': 'Dash',
#    'timestamp': '2022-04-05T13:11:36'},
#   'visualization_settings': {'table.pivot_column': 'Null',
#    'table.cell_column': 'Extra'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2022-04-05T12:43:46',
#   'public_uuid': None},
#  {'description': 'Marketing Started October 1, For Workshops scheduled during October week 2',
#   'archived': False,
#   'collection_position': None,
#   'table_id': 17,
#   'result_metadata': [{'description': None,
#     'semantic_type': 'type/Source',
#     'coercion_strategy': None,
#     'name': 'resource_id',
#     'settings': None,
#     'field_ref': ['field', 183, None],
#     'effective_type': 'type/BigInteger',
#     'id': 183,
#     'display_name': 'resource_id',
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 1.0,
#        'q1': 1.0,
#        'q3': 1.0,
#        'max': 1.0,
#        'sd': 0.0,
#        'avg': 1.0}}},
#     'base_type': 'type/BigInteger'},
#    {'display_name': 'Count',
#     'semantic_type': 'type/Quantity',
#     'field_ref': ['aggregation', 0],
#     'name': 'count',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'fingerprint': {'global': {'distinct-count': 4, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 725.0,
#        'q1': 882.0,
#        'q3': 1479.0,
#        'max': 1652.0,
#        'sd': 393.93950466198913,
#        'avg': 1180.5}}}}],
#   'creator': {'email': 'milan@frontrow.co.in',
#    'first_name': 'Milan',
#    'last_login': '2022-05-09T08:01:26',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 126,
#    'last_name': 'Mohanty',
#    'date_joined': '2021-05-12T09:24:30',
#    'common_name': 'Milan Mohanty'},
#   'database_id': 3,
#   'enable_embedding': False,
#   'collection_id': None,
#   'query_type': 'query',
#   'name': 'WS Week2 Orders: October1 Marketing',
#   'creator_id': 126,
#   'updated_at': '2022-05-11T09:15:08',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'database': 3,
#    'type': 'query',
#    'query': {'source-table': 17,
#     'filter': ['and',
#      ['=', ['field', 183, None], 178, 191, 172, 161, 189],
#      ['=', ['field', 180, None], 'COMPLETED'],
#      ['>', ['field', 176, None], '2021-09-28'],
#      ['=', ['field', 176, None], '2021-10-01']],
#     'aggregation': [['count']],
#     'breakout': [['field', 183, None]]}},
#   'id': 260,
#   'display': 'table',
#   'last-edit-info': {'id': 126,
#    'email': 'milan@frontrow.co.in',
#    'first_name': 'Milan',
#    'last_name': 'Mohanty',
#    'timestamp': '2021-10-01T16:09:31'},
#   'visualization_settings': {'table.pivot_column': 'resource_id',
#    'table.cell_column': 'count'},
#   'collection': None,
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2021-10-01T16:09:31',
#   'public_uuid': None},
#  {'description': None,
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'course_batch_id',
#     'field_ref': ['field',
#      'course_batch_id',
#      {'base-type': 'type/BigInteger'}],
#     'name': 'course_batch_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 9328.0,
#        'q1': 9328.0,
#        'q3': 9328.0,
#        'max': 9328.0,
#        'sd': None,
#        'avg': 9328.0}}}},
#    {'display_name': 'course_id',
#     'field_ref': ['field', 'course_id', {'base-type': 'type/BigInteger'}],
#     'name': 'course_id',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 231.0,
#        'q1': 231.0,
#        'q3': 231.0,
#        'max': 231.0,
#        'sd': None,
#        'avg': 231.0}}}},
#    {'display_name': 'class_start_time',
#     'field_ref': ['field', 'class_start_time', {'base-type': 'type/DateTime'}],
#     'name': 'class_start_time',
#     'base_type': 'type/DateTime',
#     'effective_type': 'type/DateTime',
#     'semantic_type': 'type/CreationTimestamp',
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/DateTime': {'earliest': '2022-05-09T21:00:00Z',
#        'latest': '2022-05-09T21:00:00Z'}}}},
#    {'display_name': 'contact',
#     'field_ref': ['field', 'contact', {'base-type': 'type/Text'}],
#     'name': 'contact',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 0.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 10.0}}}},
#    {'display_name': 'metadata',
#     'field_ref': ['field', 'metadata', {'base-type': 'type/Text'}],
#     'name': 'metadata',
#     'base_type': 'type/Text',
#     'effective_type': 'type/Text',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Text': {'percent-json': 1.0,
#        'percent-url': 0.0,
#        'percent-email': 0.0,
#        'percent-state': 0.0,
#        'average-length': 230.0}}}}],
#   'creator': {'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_login': '2022-05-13T14:24:53',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 437,
#    'last_name': 'Dash',
#    'date_joined': '2021-11-01T02:43:45',
#    'common_name': 'Mihir Dash'},
#   'database_id': 14,
#   'enable_embedding': False,
#   'collection_id': 109,
#   'query_type': 'native',
#   'name': 'WS-Reg(UTM)',
#   'creator_id': 437,
#   'updated_at': '2022-05-09T06:39:12',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'type': 'native',
#    'native': {'template-tags': {},
#     'query': 'SELECT\n  content.course_batch.id as course_batch_id,\n  content.course.id as course_id,\n  content.course_batch_content.start_date + interval \'5\' hour + interval \'30\' minute AS class_start_time,\n  user.user.contact,\n  MIN(content.user_lead.metadata) as metadata\nFROM\n  content.course_batch_user_mapping\n  INNER JOIN\n    user.user\n    ON user.user.id = content.course_batch_user_mapping.user_id\n  LEFT JOIN\n    "order".frontrow_order\n    ON "order".frontrow_order.user_id = user.user.id\n  LEFT JOIN\n    content.course_batch\n    ON content.course_batch.id = content.course_batch_user_mapping.course_batch_id\n  INNER JOIN\n    content.course \n    ON content.course.id = content.course_batch.course_id\n  LEFT JOIN\n    content.course_batch_module\n    ON content.course_batch_module.course_batch_id = content.course_batch.id\n  INNER JOIN\n    content.course_batch_content\n    ON content.course_batch_content.course_batch_module_id = content.course_batch_module.id\n  LEFT JOIN\n    content.instructor \n    ON content.instructor.id = content.course_batch.instructor_id\n  LEFT JOIN\n    content.user_lead\n    ON content.user_lead.contact = user.user.contact\nWHERE\n  content.course.resource_type IN (\'WORKSHOP\')\n  AND "order".frontrow_order.resource_type IN (\'WORKSHOP\')\n  AND content.course_batch_content.start_date + interval \'5\' hour + interval \'30\' minute >= date_parse(\'2022-02-14\',\'%Y-%m-%d\')\n  AND content.course_batch_content.start_date + interval \'5\' hour + interval \'30\' minute <= now() + interval \'1\' day\ngroup by content.course_batch.id, content.course.id, content.course_batch_content.start_date, user.user.contact\nORDER by\n  content.course_batch_content.start_date DESC\n  '},
#    'database': 14},
#   'id': 446,
#   'display': 'table',
#   'last-edit-info': {'id': 437,
#    'email': 'mihir.dash@frontrow.co.in',
#    'first_name': 'Mihir',
#    'last_name': 'Dash',
#    'timestamp': '2022-05-09T06:39:11'},
#   'visualization_settings': {'table.pivot_column': 'name',
#    'table.cell_column': 'user_id'},
#   'collection': {'authority_level': None,
#    'description': None,
#    'archived': False,
#    'slug': 'order_reports',
#    'color': '#509EE3',
#    'name': 'Order Reports',
#    'personal_owner_id': None,
#    'id': 109,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2022-04-12T10:45:19',
#   'public_uuid': None},
#  {'description': '',
#   'archived': False,
#   'collection_position': None,
#   'table_id': None,
#   'result_metadata': [{'display_name': 'count(*)',
#     'field_ref': ['field', 'count(*)', {'base-type': 'type/BigInteger'}],
#     'name': 'count(*)',
#     'base_type': 'type/BigInteger',
#     'effective_type': 'type/BigInteger',
#     'semantic_type': None,
#     'fingerprint': {'global': {'distinct-count': 1, 'nil%': 0.0},
#      'type': {'type/Number': {'min': 21238.0,
#        'q1': 21238.0,
#        'q3': 21238.0,
#        'max': 21238.0,
#        'sd': None,
#        'avg': 21238.0}}}}],
#   'creator': {'email': 'pranay@frontrow.co.in',
#    'first_name': 'Pranay',
#    'last_login': '2022-05-10T05:48:48',
#    'is_qbnewb': False,
#    'is_superuser': False,
#    'id': 20,
#    'last_name': 'Bagrecha',
#    'date_joined': '2020-09-26T06:13:57',
#    'common_name': 'Pranay Bagrecha'},
#   'database_id': 6,
#   'enable_embedding': False,
#   'collection_id': 159,
#   'query_type': 'native',
#   'name': 'YM Total Instructor Messages Count By Day and Template ID',
#   'creator_id': 20,
#   'updated_at': '2022-04-06T06:29:06',
#   'made_public_by_id': None,
#   'embedding_params': None,
#   'cache_ttl': None,
#   'dataset_query': {'database': 6,
#    'native': {'template-tags': {'start_date': {'id': '1d46c602-ab87-4e9f-becf-4efdca6f84dc',
#       'name': 'start_date',
#       'display-name': 'Start date',
#       'type': 'date',
#       'default': None},
#      'end_date': {'id': '166014b4-4876-d766-ff00-31d5ffe9872a',
#       'name': 'end_date',
#       'display-name': 'End date',
#       'type': 'date',
#       'default': None},
#      'template_id': {'id': '83c06e15-4a97-c5ab-ab77-d96684451fd0',
#       'name': 'template_id',
#       'display-name': 'Template ID',
#       'type': 'text'}},
#     'query': 'select count(*) from whatsapp_audit \nwhere from_contact="918297560747" \n[[AND template_id = {{template_id}}]]\n[[AND created_at >= CONCAT(STR_TO_DATE({{start_date}} - INTERVAL 1 DAY, \'%Y-%m-%d\'), \' 18:30:00\')]]\n[[AND created_at < CONCAT({{end_date}}, \' 18:30:00\')]]'},
#    'type': 'native'},
#   'id': 401,
#   'display': 'scalar',
#   'last-edit-info': {'id': 2,
#    'email': 'shiva@frontrow.co.in',
#    'first_name': 'Shiva',
#    'last_name': 'Chandra',
#    'timestamp': '2022-02-17T08:03:10'},
#   'visualization_settings': {},
#   'collection': {'authority_level': None,
#    'description': None,
#    'archived': False,
#    'slug': 'chat',
#    'color': '#509EE3',
#    'name': 'Chat',
#    'personal_owner_id': None,
#    'id': 159,
#    'location': '/',
#    'namespace': None},
#   'favorite': False,
#   'dataset': False,
#   'created_at': '2022-02-16T17:26:04',
#   'public_uuid': None}]

# %%
res = requests.post('http://metabase.frontrow.co.in/api/card/424/query/json', 
              headers = {'Content-Type': 'application/json',
                        'X-Metabase-Session': token
                        }
            )
df_sa=pd.DataFrame(res.json())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): metabase.frontrow.co.in:80
# DEBUG:urllib3.connectionpool:http://metabase.frontrow.co.in:80 "POST /api/card/424/query/json HTTP/1.1" 200 None

# %%
res = requests.post('http://metabase.frontrow.co.in/api/card/465/query/json', 
              headers = {'Content-Type': 'application/json',
                        'X-Metabase-Session': token
                        }
            )
df_uc=pd.DataFrame(res.json())
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTP connection (1): metabase.frontrow.co.in:80
# DEBUG:urllib3.connectionpool:http://metabase.frontrow.co.in:80 "POST /api/card/465/query/json HTTP/1.1" 200 None

# %%
df_uc.drop_duplicates(subset=['class_start_time','instructor_id','user_id'],inplace=True)

# %%
df_ucg=df_uc.groupby(by=['class_start_time','instructor_id']).agg({'user_id':'count'})
df_ucg.reset_index(inplace=True)
df_ucg['class_start_time']=pd.to_datetime(df_ucg['class_start_time']).dt.tz_localize(None)
df_ucg.rename(columns={'user_id':'user_count'},inplace=True)

# %%
df_ucg
# Out:
#        class_start_time  instructor_id  user_count
# 0   2022-05-12 20:00:00             44           8
# 1   2022-05-12 20:00:00            110           5
# 2   2022-05-12 20:00:00            187           2
# 3   2022-05-12 20:00:00            219           4
# 4   2022-05-12 20:00:00            284           2
# ..                  ...            ...         ...
# 164 2022-05-13 19:30:00            650          11
# 165 2022-05-13 19:45:00             24           9
# 166 2022-05-13 19:45:00             94           3
# 167 2022-05-13 19:45:00            172          10
# 168 2022-05-13 19:45:00            245          21
#
# [169 rows x 3 columns]

# %%
df_sa=df_sa[df_sa['is_cancelled']!=True]
df_sa
# Out:
#      user_id     batch_start_date  instructor_id              left_at  \
# 0     735256  2022-05-13T19:45:00            172                 None
# 1     302325  2022-05-13T19:45:00             24                 None
# 2    1258756  2022-05-13T19:45:00            245                 None
# 3    1521429  2022-04-06T19:45:00             94                 None
# 4    1071493  2022-03-23T19:30:00            160                 None
# ..       ...                  ...            ...                  ...
# 171   850573  2022-04-26T20:00:00            110  2022-05-12 21:23:16
# 172   248140  2022-04-26T20:00:00            219  2022-05-12 20:51:13
# 174  1244555  2022-05-12T20:00:00            419  2022-05-12 20:52:17
# 175  1582203  2022-05-12T20:00:00            537  2022-05-12 21:06:40
# 176  1597027  2022-05-12T20:00:00            549                 None
#
#         class_start_time       instructor_name  is_cancelled  \
# 0    2022-05-13T19:45:00     Shreejita Francis         False
# 1    2022-05-13T19:45:00          Vikrant Puri         False
# 2    2022-05-13T19:45:00    Richa Shyam Sharma         False
# 3    2022-05-13T19:45:00        Sanjay Goswami         False
# 4    2022-05-13T19:30:00     Surojit Mukherjee         False
# ..                   ...                   ...           ...
# 171  2022-05-12T20:00:00        Abhijeet Singh         False
# 172  2022-05-12T20:00:00       Anuradha Thakur         False
# 174  2022-05-12T20:00:00  Priyesh Kumar Pandey         False
# 175  2022-05-12T20:00:00           Bantai Baba         False
# 176  2022-05-12T20:00:00        Prateek Tiwari         False
#
#           first_drop_off  lesson_id has_attended  \
# 0                   None      59567           NO
# 1                   None      59592          YES
# 2                   None      59553          YES
# 3                   None      59731          YES
# 4                   None      41009          YES
# ..                   ...        ...          ...
# 171  2022-05-12 20:54:32      50184          YES
# 172                 None      50894          YES
# 174                 None      59514          YES
# 175                 None      56912          YES
# 176                 None      59706          YES
#
#                                 course_name  \
# 0                   Classical Singing Class
# 1                      Learn Piano Workshop
# 2                   Bollywood Singing Class
# 3                    Learn Piano | Advanced
# 4    Learn Bollywood Singing | Intermediate
# ..                                      ...
# 171      Learn Music Composition | Beginner
# 172  Learn Classical Singing | Intermediate
# 174                 Classical Singing Class
# 175     Learn Youtube Growth | Intermediate
# 176   Learn Screen Writing | 1 Day Workshop
#
#                                         link  batch_id            joined_at  \
# 0    https://link.frontrow.co.in/VowjVEcHWpb      9618                 None
# 1    https://link.frontrow.co.in/WowjVEcHWpb      9643  2022-05-13 19:39:12
# 2    https://link.frontrow.co.in/UowjVEcHWpb      9604  2022-05-13 19:38:09
# 3    https://link.frontrow.co.in/dnCSbyonTpb      6869  2022-05-13 19:32:57
# 4    https://link.frontrow.co.in/Zfy5cTUCWpb      6238  2022-05-13 19:29:02
# ..                                       ...       ...                  ...
# 171  https://link.frontrow.co.in/a2xg4po2Upb      8030  2022-05-12 20:08:23
# 172  https://link.frontrow.co.in/ga9x4po2Upb      8113  2022-05-12 19:58:49
# 174  https://link.frontrow.co.in/ja9x4po2Upb      9565  2022-05-12 19:57:56
# 175  https://link.frontrow.co.in/pnCSbyonTpb      9148  2022-05-12 19:58:06
# 176  https://link.frontrow.co.in/la9x4po2Upb      9757  2022-05-12 19:53:35
#
#           class_end_time  dropoff_count  course_type     contact  course_id
# 0    2022-05-13T21:15:00              0     WORKSHOP  7872413474        233
# 1    2022-05-13T21:15:00              0     WORKSHOP  9212079425        234
# 2    2022-05-13T21:15:00              0     WORKSHOP  8291736609        232
# 3    2022-05-13T20:45:00              0  LIVE_COURSE  9720438568        445
# 4    2022-05-13T20:30:00              0  LIVE_COURSE  9810724384        469
# ..                   ...            ...          ...         ...        ...
# 171  2022-05-12T21:30:00              1  LIVE_COURSE  9919607008        455
# 172  2022-05-12T21:00:00              0  LIVE_COURSE  8920206642        468
# 174  2022-05-12T21:30:00              0     WORKSHOP  8458907873        233
# 175  2022-05-12T21:00:00              0  LIVE_COURSE  9082941014        518
# 176  2022-05-12T22:00:00              0     WORKSHOP  7977924192        540
#
# [169 rows x 19 columns]

# %%
df_sa['joined_at']=pd.to_datetime(df_sa['joined_at'])
df_sa['class_start_time']=pd.to_datetime(df_sa['class_start_time'])
df_sa=pd.merge(df_sa,df_ucg,how='left',on=['class_start_time','instructor_id'])
df_sa
# Out:
#      user_id     batch_start_date  instructor_id              left_at  \
# 0     735256  2022-05-13T19:45:00            172                 None
# 1     302325  2022-05-13T19:45:00             24                 None
# 2    1258756  2022-05-13T19:45:00            245                 None
# 3    1521429  2022-04-06T19:45:00             94                 None
# 4    1071493  2022-03-23T19:30:00            160                 None
# ..       ...                  ...            ...                  ...
# 164   850573  2022-04-26T20:00:00            110  2022-05-12 21:23:16
# 165   248140  2022-04-26T20:00:00            219  2022-05-12 20:51:13
# 166  1244555  2022-05-12T20:00:00            419  2022-05-12 20:52:17
# 167  1582203  2022-05-12T20:00:00            537  2022-05-12 21:06:40
# 168  1597027  2022-05-12T20:00:00            549                 None
#
#        class_start_time       instructor_name  is_cancelled  \
# 0   2022-05-13 19:45:00     Shreejita Francis         False
# 1   2022-05-13 19:45:00          Vikrant Puri         False
# 2   2022-05-13 19:45:00    Richa Shyam Sharma         False
# 3   2022-05-13 19:45:00        Sanjay Goswami         False
# 4   2022-05-13 19:30:00     Surojit Mukherjee         False
# ..                  ...                   ...           ...
# 164 2022-05-12 20:00:00        Abhijeet Singh         False
# 165 2022-05-12 20:00:00       Anuradha Thakur         False
# 166 2022-05-12 20:00:00  Priyesh Kumar Pandey         False
# 167 2022-05-12 20:00:00           Bantai Baba         False
# 168 2022-05-12 20:00:00        Prateek Tiwari         False
#
#           first_drop_off  lesson_id has_attended  \
# 0                   None      59567           NO
# 1                   None      59592          YES
# 2                   None      59553          YES
# 3                   None      59731          YES
# 4                   None      41009          YES
# ..                   ...        ...          ...
# 164  2022-05-12 20:54:32      50184          YES
# 165                 None      50894          YES
# 166                 None      59514          YES
# 167                 None      56912          YES
# 168                 None      59706          YES
#
#                                 course_name  \
# 0                   Classical Singing Class
# 1                      Learn Piano Workshop
# 2                   Bollywood Singing Class
# 3                    Learn Piano | Advanced
# 4    Learn Bollywood Singing | Intermediate
# ..                                      ...
# 164      Learn Music Composition | Beginner
# 165  Learn Classical Singing | Intermediate
# 166                 Classical Singing Class
# 167     Learn Youtube Growth | Intermediate
# 168   Learn Screen Writing | 1 Day Workshop
#
#                                         link  batch_id           joined_at  \
# 0    https://link.frontrow.co.in/VowjVEcHWpb      9618                 NaT
# 1    https://link.frontrow.co.in/WowjVEcHWpb      9643 2022-05-13 19:39:12
# 2    https://link.frontrow.co.in/UowjVEcHWpb      9604 2022-05-13 19:38:09
# 3    https://link.frontrow.co.in/dnCSbyonTpb      6869 2022-05-13 19:32:57
# 4    https://link.frontrow.co.in/Zfy5cTUCWpb      6238 2022-05-13 19:29:02
# ..                                       ...       ...                 ...
# 164  https://link.frontrow.co.in/a2xg4po2Upb      8030 2022-05-12 20:08:23
# 165  https://link.frontrow.co.in/ga9x4po2Upb      8113 2022-05-12 19:58:49
# 166  https://link.frontrow.co.in/ja9x4po2Upb      9565 2022-05-12 19:57:56
# 167  https://link.frontrow.co.in/pnCSbyonTpb      9148 2022-05-12 19:58:06
# 168  https://link.frontrow.co.in/la9x4po2Upb      9757 2022-05-12 19:53:35
#
#           class_end_time  dropoff_count  course_type     contact  course_id  \
# 0    2022-05-13T21:15:00              0     WORKSHOP  7872413474        233
# 1    2022-05-13T21:15:00              0     WORKSHOP  9212079425        234
# 2    2022-05-13T21:15:00              0     WORKSHOP  8291736609        232
# 3    2022-05-13T20:45:00              0  LIVE_COURSE  9720438568        445
# 4    2022-05-13T20:30:00              0  LIVE_COURSE  9810724384        469
# ..                   ...            ...          ...         ...        ...
# 164  2022-05-12T21:30:00              1  LIVE_COURSE  9919607008        455
# 165  2022-05-12T21:00:00              0  LIVE_COURSE  8920206642        468
# 166  2022-05-12T21:30:00              0     WORKSHOP  8458907873        233
# 167  2022-05-12T21:00:00              0  LIVE_COURSE  9082941014        518
# 168  2022-05-12T22:00:00              0     WORKSHOP  7977924192        540
#
#      user_count
# 0            10
# 1             9
# 2            21
# 3             3
# 4             6
# ..          ...
# 164           5
# 165           4
# 166          10
# 167          12
# 168          15
#
# [169 rows x 20 columns]

# %%
from datetime import datetime
dt=datetime.now()
df_sa['curr_dt']=dt
st=df_sa['class_start_time'].tolist()
ja=df_sa['joined_at'].tolist()
i_n=df_sa['instructor_name'].tolist()
cbi=df_sa['batch_id'].tolist()
ct=df_sa['course_type'].tolist()
uc=df_sa['user_count'].tolist()
df_sa
# Out:
#      user_id     batch_start_date  instructor_id              left_at  \
# 0     735256  2022-05-13T19:45:00            172                 None
# 1     302325  2022-05-13T19:45:00             24                 None
# 2    1258756  2022-05-13T19:45:00            245                 None
# 3    1521429  2022-04-06T19:45:00             94                 None
# 4    1071493  2022-03-23T19:30:00            160                 None
# ..       ...                  ...            ...                  ...
# 164   850573  2022-04-26T20:00:00            110  2022-05-12 21:23:16
# 165   248140  2022-04-26T20:00:00            219  2022-05-12 20:51:13
# 166  1244555  2022-05-12T20:00:00            419  2022-05-12 20:52:17
# 167  1582203  2022-05-12T20:00:00            537  2022-05-12 21:06:40
# 168  1597027  2022-05-12T20:00:00            549                 None
#
#        class_start_time       instructor_name  is_cancelled  \
# 0   2022-05-13 19:45:00     Shreejita Francis         False
# 1   2022-05-13 19:45:00          Vikrant Puri         False
# 2   2022-05-13 19:45:00    Richa Shyam Sharma         False
# 3   2022-05-13 19:45:00        Sanjay Goswami         False
# 4   2022-05-13 19:30:00     Surojit Mukherjee         False
# ..                  ...                   ...           ...
# 164 2022-05-12 20:00:00        Abhijeet Singh         False
# 165 2022-05-12 20:00:00       Anuradha Thakur         False
# 166 2022-05-12 20:00:00  Priyesh Kumar Pandey         False
# 167 2022-05-12 20:00:00           Bantai Baba         False
# 168 2022-05-12 20:00:00        Prateek Tiwari         False
#
#           first_drop_off  lesson_id has_attended  ...  \
# 0                   None      59567           NO  ...
# 1                   None      59592          YES  ...
# 2                   None      59553          YES  ...
# 3                   None      59731          YES  ...
# 4                   None      41009          YES  ...
# ..                   ...        ...          ...  ...
# 164  2022-05-12 20:54:32      50184          YES  ...
# 165                 None      50894          YES  ...
# 166                 None      59514          YES  ...
# 167                 None      56912          YES  ...
# 168                 None      59706          YES  ...
#
#                                         link batch_id           joined_at  \
# 0    https://link.frontrow.co.in/VowjVEcHWpb     9618                 NaT
# 1    https://link.frontrow.co.in/WowjVEcHWpb     9643 2022-05-13 19:39:12
# 2    https://link.frontrow.co.in/UowjVEcHWpb     9604 2022-05-13 19:38:09
# 3    https://link.frontrow.co.in/dnCSbyonTpb     6869 2022-05-13 19:32:57
# 4    https://link.frontrow.co.in/Zfy5cTUCWpb     6238 2022-05-13 19:29:02
# ..                                       ...      ...                 ...
# 164  https://link.frontrow.co.in/a2xg4po2Upb     8030 2022-05-12 20:08:23
# 165  https://link.frontrow.co.in/ga9x4po2Upb     8113 2022-05-12 19:58:49
# 166  https://link.frontrow.co.in/ja9x4po2Upb     9565 2022-05-12 19:57:56
# 167  https://link.frontrow.co.in/pnCSbyonTpb     9148 2022-05-12 19:58:06
# 168  https://link.frontrow.co.in/la9x4po2Upb     9757 2022-05-12 19:53:35
#
#           class_end_time dropoff_count  course_type     contact course_id  \
# 0    2022-05-13T21:15:00             0     WORKSHOP  7872413474       233
# 1    2022-05-13T21:15:00             0     WORKSHOP  9212079425       234
# 2    2022-05-13T21:15:00             0     WORKSHOP  8291736609       232
# 3    2022-05-13T20:45:00             0  LIVE_COURSE  9720438568       445
# 4    2022-05-13T20:30:00             0  LIVE_COURSE  9810724384       469
# ..                   ...           ...          ...         ...       ...
# 164  2022-05-12T21:30:00             1  LIVE_COURSE  9919607008       455
# 165  2022-05-12T21:00:00             0  LIVE_COURSE  8920206642       468
# 166  2022-05-12T21:30:00             0     WORKSHOP  8458907873       233
# 167  2022-05-12T21:00:00             0  LIVE_COURSE  9082941014       518
# 168  2022-05-12T22:00:00             0     WORKSHOP  7977924192       540
#
#      user_count                    curr_dt
# 0            10 2022-05-13 19:55:39.274340
# 1             9 2022-05-13 19:55:39.274340
# 2            21 2022-05-13 19:55:39.274340
# 3             3 2022-05-13 19:55:39.274340
# 4             6 2022-05-13 19:55:39.274340
# ..          ...                        ...
# 164           5 2022-05-13 19:55:39.274340
# 165           4 2022-05-13 19:55:39.274340
# 166          10 2022-05-13 19:55:39.274340
# 167          12 2022-05-13 19:55:39.274340
# 168          15 2022-05-13 19:55:39.274340
#
# [169 rows x 21 columns]

# %%
df_sa['td']=(df_sa['curr_dt']-df_sa['class_start_time']).astype('timedelta64[m]')
df_s=df_sa
df_sa=df_sa[df_sa['has_attended']=="NO"]
df_sa=df_sa[df_sa['td']<=5]

# %%
df_sa=df_sa[df_sa['td']>=3]

# %%
df_sa=df_sa[df_sa['joined_at'].isna()]

# %%
import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe
from oauth2client.service_account import ServiceAccountCredentials
scope =["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds =ServiceAccountCredentials.from_json_keyfile_name("credentials.json", scope)
client = gspread.authorize(creds)
spreadsheet = client.open("Course - IDs")
kmk="Sheet4"
wks1=spreadsheet.worksheet(kmk)
print()
dfpn=pd.DataFrame(wks1.get_all_records())
dfpn
# Out:
# DEBUG:urllib3.util.retry:Converted retries value: 3 -> Retry(total=3, connect=None, read=None, redirect=None, status=None)
# DEBUG:google.auth.transport.requests:Making request: POST https://oauth2.googleapis.com/token
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): oauth2.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://oauth2.googleapis.com:443 "POST /token HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): www.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://www.googleapis.com:443 "GET /drive/v3/files?q=mimeType%3D%22application%2Fvnd.google-apps.spreadsheet%22+and+name+%3D+%22Course+-+IDs%22&pageSize=1000&supportsAllDrives=True&includeItemsFromAllDrives=True&fields=kind%2CnextPageToken%2Cfiles%28id%2Cname%2CcreatedTime%2CmodifiedTime%29 HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): sheets.googleapis.com:443
# DEBUG:urllib3.connectionpool:https://sheets.googleapis.com:443 "GET /v4/spreadsheets/1Pa-O25F48wBzRKC76I988F_FBUhwmShgxb3gehBrkp4?includeGridData=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://sheets.googleapis.com:443 "GET /v4/spreadsheets/1Pa-O25F48wBzRKC76I988F_FBUhwmShgxb3gehBrkp4?includeGridData=false HTTP/1.1" 200 None
# DEBUG:urllib3.connectionpool:https://sheets.googleapis.com:443 "GET /v4/spreadsheets/1Pa-O25F48wBzRKC76I988F_FBUhwmShgxb3gehBrkp4/values/%27Sheet4%27 HTTP/1.1" 200 None
#      course_id  Slack Codes
# 0          161  U031DQVCCMT
# 1          178  U031DQVCCMT
# 2          189  U031DQVCCMT
# 3          194  U031DQVCCMT
# 4          233  U031DQVCCMT
# ..         ...          ...
# 372        558  U02DHHV6MPD
# 373        557  U02DHHV6MPD
# 374        552  U034L9K7S30
# 375        480  U02DHHV6MPD
# 376        475  U02DHHV6MPD
#
# [377 rows x 2 columns]

# %%
df_sa=pd.merge(df_sa, dfpn, how='left', left_on=['course_id'], right_on=['course_id'])

# %%
df_sa_copy=df_sa

# %%
df_sa
# Out:
# Empty DataFrame
# Columns: [user_id, batch_start_date, instructor_id, left_at, class_start_time, instructor_name, is_cancelled, first_drop_off, lesson_id, has_attended, course_name, link, batch_id, joined_at, class_end_time, dropoff_count, course_type, contact, user_count, curr_dt, td, course_id, Slack Codes]
# Index: []
#
# [0 rows x 23 columns]

# %%
import pickle
of=open("sl.pkl","rb")
lst=pickle.load(of)
of.close()
df_sa=df_sa[~df_sa['batch_id'].isin(lst)]
cip=df_sa_copy['batch_id'].tolist()
ofn=open("sl.pkl","wb")
pickle.dump(cip,ofn)
ofn.close()
lst,cip
# Out:
# ([], [])

# %%
st=df_sa['class_start_time'].tolist()
ja=df_sa['joined_at'].tolist()
i_n=df_sa['instructor_name'].tolist()
cbi=df_sa['batch_id'].tolist()
i_d=df_sa['instructor_id'].tolist()
c_n=df_sa['course_name'].tolist()
c_t=df_sa['course_type'].tolist()
s_c=df_sa['Slack Codes'].tolist()
u_c=df_sa['user_count'].tolist()

# %%
msg=""
for kk in range(len(cbi)):
    p0='Start Time: '+str(st[kk])
    p1='course_name: '+str(c_n[kk])
    p2='instructor_id: '+str(i_d[kk])
    p3="Instructor Name: "+str(i_n[kk])
    p4="Batch ID: "+str(cbi[kk])
    p5="Course Type: "+str(c_t[kk])
    p6="User Count: "+str(u_c[kk])
    msg=msg+p0+'\n'+p1+'\n'+p2+'\n'+p3+'\n'+p4+'\n'+p5+'\n'+p6+'\n'+"-----------------------------"+'\n'
    import logging
    logging.basicConfig(level=logging.DEBUG)

    import os
    from slack_sdk import WebClient
    from slack_sdk.errors import SlackApiError

    slack_token = "xoxb-882099602902-3377088964865-zeCsUYj0nu0YffEkpHZ3tw1t"
    client = WebClient(token=slack_token)

    try:
        response = client.chat_postMessage(
            channel=str(s_c[kk]),
            text=msg,
        )
    except SlackApiError as e:
        # You will get a SlackApiError if "ok" is False
        assert e.response["error"]
        print(e)

# %%
import json
import sys
import random
if(msg!=""):
    if __name__ == '__main__':
        url = "https://hooks.slack.com/services/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"
        message = (msg)
        title = (f"3 MINUTES LATE ALERT :zap:")
        slack_data = {
            "username": "NotificationBot",
            "icon_emoji": ":satellite:",
            #"channel" : "#somerandomcahnnel",
            "attachments": [
                {
                    "color": "#FFFF00",
                    "fields": [
                        {
                            "title": title,
                            "value": message,
                            "short": "false",
                        }
                    ]
                }
            ]
        }
        byte_length = str(sys.getsizeof(slack_data))
        headers = {'Content-Type': "application/json", 'Content-Length': byte_length}
        response = requests.post(url, data=json.dumps(slack_data), headers=headers)
        if response.status_code != 200:
            raise Exception(response.status_code, response.text)

# %%
df_s
# Out:
#      user_id     batch_start_date  instructor_id              left_at  \
# 0     735256  2022-05-13T19:45:00            172                 None
# 1     302325  2022-05-13T19:45:00             24                 None
# 2    1258756  2022-05-13T19:45:00            245                 None
# 3    1521429  2022-04-06T19:45:00             94                 None
# 4    1071493  2022-03-23T19:30:00            160                 None
# ..       ...                  ...            ...                  ...
# 164   850573  2022-04-26T20:00:00            110  2022-05-12 21:23:16
# 165   248140  2022-04-26T20:00:00            219  2022-05-12 20:51:13
# 166  1244555  2022-05-12T20:00:00            419  2022-05-12 20:52:17
# 167  1582203  2022-05-12T20:00:00            537  2022-05-12 21:06:40
# 168  1597027  2022-05-12T20:00:00            549                 None
#
#        class_start_time       instructor_name  is_cancelled  \
# 0   2022-05-13 19:45:00     Shreejita Francis         False
# 1   2022-05-13 19:45:00          Vikrant Puri         False
# 2   2022-05-13 19:45:00    Richa Shyam Sharma         False
# 3   2022-05-13 19:45:00        Sanjay Goswami         False
# 4   2022-05-13 19:30:00     Surojit Mukherjee         False
# ..                  ...                   ...           ...
# 164 2022-05-12 20:00:00        Abhijeet Singh         False
# 165 2022-05-12 20:00:00       Anuradha Thakur         False
# 166 2022-05-12 20:00:00  Priyesh Kumar Pandey         False
# 167 2022-05-12 20:00:00           Bantai Baba         False
# 168 2022-05-12 20:00:00        Prateek Tiwari         False
#
#           first_drop_off  lesson_id has_attended  ... batch_id  \
# 0                   None      59567           NO  ...     9618
# 1                   None      59592          YES  ...     9643
# 2                   None      59553          YES  ...     9604
# 3                   None      59731          YES  ...     6869
# 4                   None      41009          YES  ...     6238
# ..                   ...        ...          ...  ...      ...
# 164  2022-05-12 20:54:32      50184          YES  ...     8030
# 165                 None      50894          YES  ...     8113
# 166                 None      59514          YES  ...     9565
# 167                 None      56912          YES  ...     9148
# 168                 None      59706          YES  ...     9757
#
#               joined_at       class_end_time dropoff_count  course_type  \
# 0                   NaT  2022-05-13T21:15:00             0     WORKSHOP
# 1   2022-05-13 19:39:12  2022-05-13T21:15:00             0     WORKSHOP
# 2   2022-05-13 19:38:09  2022-05-13T21:15:00             0     WORKSHOP
# 3   2022-05-13 19:32:57  2022-05-13T20:45:00             0  LIVE_COURSE
# 4   2022-05-13 19:29:02  2022-05-13T20:30:00             0  LIVE_COURSE
# ..                  ...                  ...           ...          ...
# 164 2022-05-12 20:08:23  2022-05-12T21:30:00             1  LIVE_COURSE
# 165 2022-05-12 19:58:49  2022-05-12T21:00:00             0  LIVE_COURSE
# 166 2022-05-12 19:57:56  2022-05-12T21:30:00             0     WORKSHOP
# 167 2022-05-12 19:58:06  2022-05-12T21:00:00             0  LIVE_COURSE
# 168 2022-05-12 19:53:35  2022-05-12T22:00:00             0     WORKSHOP
#
#         contact course_id user_count                    curr_dt      td
# 0    7872413474       233         10 2022-05-13 19:55:39.274340    10.0
# 1    9212079425       234          9 2022-05-13 19:55:39.274340    10.0
# 2    8291736609       232         21 2022-05-13 19:55:39.274340    10.0
# 3    9720438568       445          3 2022-05-13 19:55:39.274340    10.0
# 4    9810724384       469          6 2022-05-13 19:55:39.274340    25.0
# ..          ...       ...        ...                        ...     ...
# 164  9919607008       455          5 2022-05-13 19:55:39.274340  1435.0
# 165  8920206642       468          4 2022-05-13 19:55:39.274340  1435.0
# 166  8458907873       233         10 2022-05-13 19:55:39.274340  1435.0
# 167  9082941014       518         12 2022-05-13 19:55:39.274340  1435.0
# 168  7977924192       540         15 2022-05-13 19:55:39.274340  1435.0
#
# [169 rows x 22 columns]

# %%
df_f=df_s

# %%
df_f
# Out:
#      user_id     batch_start_date  instructor_id              left_at  \
# 0     735256  2022-05-13T19:45:00            172                 None
# 1     302325  2022-05-13T19:45:00             24                 None
# 2    1258756  2022-05-13T19:45:00            245                 None
# 3    1521429  2022-04-06T19:45:00             94                 None
# 4    1071493  2022-03-23T19:30:00            160                 None
# ..       ...                  ...            ...                  ...
# 164   850573  2022-04-26T20:00:00            110  2022-05-12 21:23:16
# 165   248140  2022-04-26T20:00:00            219  2022-05-12 20:51:13
# 166  1244555  2022-05-12T20:00:00            419  2022-05-12 20:52:17
# 167  1582203  2022-05-12T20:00:00            537  2022-05-12 21:06:40
# 168  1597027  2022-05-12T20:00:00            549                 None
#
#        class_start_time       instructor_name  is_cancelled  \
# 0   2022-05-13 19:45:00     Shreejita Francis         False
# 1   2022-05-13 19:45:00          Vikrant Puri         False
# 2   2022-05-13 19:45:00    Richa Shyam Sharma         False
# 3   2022-05-13 19:45:00        Sanjay Goswami         False
# 4   2022-05-13 19:30:00     Surojit Mukherjee         False
# ..                  ...                   ...           ...
# 164 2022-05-12 20:00:00        Abhijeet Singh         False
# 165 2022-05-12 20:00:00       Anuradha Thakur         False
# 166 2022-05-12 20:00:00  Priyesh Kumar Pandey         False
# 167 2022-05-12 20:00:00           Bantai Baba         False
# 168 2022-05-12 20:00:00        Prateek Tiwari         False
#
#           first_drop_off  lesson_id has_attended  ... batch_id  \
# 0                   None      59567           NO  ...     9618
# 1                   None      59592          YES  ...     9643
# 2                   None      59553          YES  ...     9604
# 3                   None      59731          YES  ...     6869
# 4                   None      41009          YES  ...     6238
# ..                   ...        ...          ...  ...      ...
# 164  2022-05-12 20:54:32      50184          YES  ...     8030
# 165                 None      50894          YES  ...     8113
# 166                 None      59514          YES  ...     9565
# 167                 None      56912          YES  ...     9148
# 168                 None      59706          YES  ...     9757
#
#               joined_at       class_end_time dropoff_count  course_type  \
# 0                   NaT  2022-05-13T21:15:00             0     WORKSHOP
# 1   2022-05-13 19:39:12  2022-05-13T21:15:00             0     WORKSHOP
# 2   2022-05-13 19:38:09  2022-05-13T21:15:00             0     WORKSHOP
# 3   2022-05-13 19:32:57  2022-05-13T20:45:00             0  LIVE_COURSE
# 4   2022-05-13 19:29:02  2022-05-13T20:30:00             0  LIVE_COURSE
# ..                  ...                  ...           ...          ...
# 164 2022-05-12 20:08:23  2022-05-12T21:30:00             1  LIVE_COURSE
# 165 2022-05-12 19:58:49  2022-05-12T21:00:00             0  LIVE_COURSE
# 166 2022-05-12 19:57:56  2022-05-12T21:30:00             0     WORKSHOP
# 167 2022-05-12 19:58:06  2022-05-12T21:00:00             0  LIVE_COURSE
# 168 2022-05-12 19:53:35  2022-05-12T22:00:00             0     WORKSHOP
#
#         contact course_id user_count                    curr_dt      td
# 0    7872413474       233         10 2022-05-13 19:55:39.274340    10.0
# 1    9212079425       234          9 2022-05-13 19:55:39.274340    10.0
# 2    8291736609       232         21 2022-05-13 19:55:39.274340    10.0
# 3    9720438568       445          3 2022-05-13 19:55:39.274340    10.0
# 4    9810724384       469          6 2022-05-13 19:55:39.274340    25.0
# ..          ...       ...        ...                        ...     ...
# 164  9919607008       455          5 2022-05-13 19:55:39.274340  1435.0
# 165  8920206642       468          4 2022-05-13 19:55:39.274340  1435.0
# 166  8458907873       233         10 2022-05-13 19:55:39.274340  1435.0
# 167  9082941014       518         12 2022-05-13 19:55:39.274340  1435.0
# 168  7977924192       540         15 2022-05-13 19:55:39.274340  1435.0
#
# [169 rows x 22 columns]

# %%
df_f=df_f[df_f['has_attended']=="NO"]
df_f=df_f[df_f['td']<=30]
df_f=df_f[df_f['td']>=5]

# %%
df_f
# Out:
#    user_id     batch_start_date  instructor_id left_at    class_start_time  \
# 0   735256  2022-05-13T19:45:00            172    None 2022-05-13 19:45:00
#
#      instructor_name  is_cancelled first_drop_off  lesson_id has_attended  \
# 0  Shreejita Francis         False           None      59567           NO
#
#    ... batch_id joined_at       class_end_time dropoff_count course_type  \
# 0  ...     9618       NaT  2022-05-13T21:15:00             0    WORKSHOP
#
#       contact course_id user_count                    curr_dt    td
# 0  7872413474       233         10 2022-05-13 19:55:39.274340  10.0
#
# [1 rows x 22 columns]

# %%
df_f=df_f[df_f['joined_at'].isna()]
df_f=pd.merge(df_f, dfpn, how='left', left_on=['course_id'], right_on=['course_id'])
df_sx=df_f

# %%
df_sx
# Out:
#    user_id     batch_start_date  instructor_id left_at    class_start_time  \
# 0   735256  2022-05-13T19:45:00            172    None 2022-05-13 19:45:00
#
#      instructor_name  is_cancelled first_drop_off  lesson_id has_attended  \
# 0  Shreejita Francis         False           None      59567           NO
#
#    ... joined_at       class_end_time  dropoff_count course_type     contact  \
# 0  ...       NaT  2022-05-13T21:15:00              0    WORKSHOP  7872413474
#
#    course_id user_count                    curr_dt    td  Slack Codes
# 0        233         10 2022-05-13 19:55:39.274340  10.0  U031DQVCCMT
#
# [1 rows x 23 columns]

# %%
import pickle
of1=open("sl2.pkl","rb")
lst1=pickle.load(of1)
of1.close()
df_f=df_f[~df_f['batch_id'].isin(lst1)]
cip1=df_sx['batch_id'].tolist()
ofn1=open("sl2.pkl","wb")
pickle.dump(cip1,ofn1)
ofn1.close()
lst1,cip1
# Out:
# ([5080], [9618])

# %%
st1=df_f['class_start_time'].tolist()
ja1=df_f['joined_at'].tolist()
i_n1=df_f['instructor_name'].tolist()
i_d1=df_f['instructor_id'].tolist()
c_n1=df_f['course_name'].tolist()
cbi1=df_f['batch_id'].tolist()
c_t1=df_f['course_type'].tolist()
s_c1=df_f['Slack Codes'].tolist()
u_c1=df_f['user_count'].tolist()

# %%
msg2=""
for kk1 in range(len(cbi1)):
    p00='Start Time: '+str(st1[kk1])
    p11='course_name: '+str(c_n1[kk1])
    p22='instructor_id: '+str(i_d1[kk1])
    p33="Instructor Name: "+str(i_n1[kk1])
    p44="Batch ID: "+str(cbi1[kk1])
    p55="course type: "+str(c_t1[kk1])
    p66="User Count: "+str(u_c1[kk1])
    msg2=msg2+p00+'\n'+p11+'\n'+p22+'\n'+p33+'\n'+p44+'\n'+p55+'\n'+p66+'\n'+"-----------------------------"+'\n'
    import logging
    logging.basicConfig(level=logging.DEBUG)

    import os
    from slack_sdk import WebClient
    from slack_sdk.errors import SlackApiError

    slack_token = "xoxb-882099602902-3377088964865-zeCsUYj0nu0YffEkpHZ3tw1t"
    client = WebClient(token=slack_token)

    try:
        response = client.chat_postMessage(
            channel=str(s_c1[kk1]),
            text=msg2
        )
    except SlackApiError as e:
        # You will get a SlackApiError if "ok" is False
        assert e.response["error"]
    
print(msg2)
# Out:
# DEBUG:slack_sdk.web.base_client:Sending a request - url: https://www.slack.com/api/chat.postMessage, query_params: {}, body_params: {}, files: {}, json_body: {'channel': 'U031DQVCCMT', 'text': 'Start Time: 2022-05-13 19:45:00\ncourse_name: Classical Singing Class\ninstructor_id: 172\nInstructor Name: Shreejita Francis\nBatch ID: 9618\ncourse type: WORKSHOP\nUser Count: 10\n-----------------------------\n'}, headers: {'Content-Type': 'application/json;charset=utf-8', 'Authorization': '(redacted)', 'User-Agent': 'Python/3.10.2 slackclient/3.15.2 Windows/10'}
# DEBUG:slack_sdk.web.base_client:Received the following response - status: 200, headers: {'date': 'Fri, 13 May 2022 14:25:23 GMT', 'server': 'Apache', 'x-powered-by': 'HHVM/4.153.1', 'access-control-allow-origin': '*', 'referrer-policy': 'no-referrer', 'x-slack-backend': 'r', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'access-control-allow-headers': 'slack-route, x-slack-version-ts, x-b3-traceid, x-b3-spanid, x-b3-parentspanid, x-b3-sampled, x-b3-flags', 'access-control-expose-headers': 'x-slack-req-id, retry-after', 'x-oauth-scopes': 'incoming-webhook,calls:read,chat:write,chat:write.customize,channels:join', 'x-accepted-oauth-scopes': 'chat:write', 'expires': 'Mon, 26 Jul 1997 05:00:00 GMT', 'cache-control': 'private, no-cache, no-store, must-revalidate', 'pragma': 'no-cache', 'x-xss-protection': '0', 'x-content-type-options': 'nosniff', 'x-slack-req-id': '4ab87ca340412f3244c2b3bb0c5f0726', 'vary': 'Accept-Encoding', 'content-type': 'application/json; charset=utf-8', 'x-envoy-upstream-service-time': '289', 'x-backend': 'main_normal main_bedrock_normal_with_overflow main_canary_with_overflow main_bedrock_canary_with_overflow main_control_with_overflow main_bedrock_control_with_overflow', 'x-server': 'slack-www-hhvm-main-iad-wc80', 'x-slack-shared-secret-outcome': 'no-match', 'via': 'envoy-www-iad-9lq9, envoy-edge-bom-tcvq', 'x-edge-backend': 'envoy-www', 'x-slack-edge-shared-secret-outcome': 'no-match', 'connection': 'close', 'transfer-encoding': 'chunked'}, body: {"ok":true,"channel":"D03B35RPJJD","ts":"1652451923.055169","message":{"bot_id":"B03AMHMFZ0V","type":"message","text":"Start Time: 2022-05-13 19:45:00\ncourse_name: Classical Singing Class\ninstructor_id: 172\nInstructor Name: Shreejita Francis\nBatch ID: 9618\ncourse type: WORKSHOP\nUser Count: 10\n-----------------------------\n","user":"U03B32LUCRF","ts":"1652451923.055169","app_id":"A03AMH7HVRT","team":"TRY2XHQSJ","bot_profile":{"id":"B03AMHMFZ0V","app_id":"A03AMH7HVRT","name":"Instructor Late DM","icons":{"image_36":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/bot_36.png","image_48":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/bot_48.png","image_72":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/service_72.png"},"deleted":false,"updated":1649416086,"team_id":"TRY2XHQSJ"},"blocks":[{"type":"rich_text","block_id":"RDp","elements":[{"type":"rich_text_section","elements":[{"type":"text","text":"Start Time: 2022-05-13 19:45:00\ncourse_name: Classical Singing Class\ninstructor_id: 172\nInstructor Name: Shreejita Francis\nBatch ID: 9618\ncourse type: WORKSHOP\nUser Count: 10\n-----------------------------"}]}]}]}}
# Start Time: 2022-05-13 19:45:00
# course_name: Classical Singing Class
# instructor_id: 172
# Instructor Name: Shreejita Francis
# Batch ID: 9618
# course type: WORKSHOP
# User Count: 10
# -----------------------------

# %%
import requests
import json
import sys
import random
if(msg2!=""):
    if __name__ == '__main__':
        url = "https://hooks.slack.com/services/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"
        message = (msg2)
        title = (f"5 MINUTES LATE ALERT :zap:")
        slack_data = {
            "username": "NotificationBot",
            "icon_emoji": ":satellite:",
            #"channel" : "#somerandomcahnnel",
            "attachments": [
                {
                    "color": "#FF0000",
                    "fields": [
                        {
                            "title": title,
                            "value": message,
                            "short": "false",
                        }
                    ]
                }
            ]
        }
        byte_length = str(sys.getsizeof(slack_data))
        headers = {'Content-Type': "application/json", 'Content-Length': byte_length}
        response = requests.post(url, data=json.dumps(slack_data), headers=headers)
        if response.status_code != 200:
            raise Exception(response.status_code, response.text)
# Out:
# DEBUG:urllib3.connectionpool:Starting new HTTPS connection (1): hooks.slack.com:443
# DEBUG:urllib3.connectionpool:https://hooks.slack.com:443 "POST /services/TRY2XHQSJ/B03ASMD227N/4or3Qfllnx3BCtaX2GgkrW2A HTTP/1.1" 200 22

# %%
import logging
logging.basicConfig(level=logging.DEBUG)

import os
from slack_sdk import WebClient
from slack_sdk.errors import SlackApiError

slack_token = "xoxb-882099602902-3377088964865-zeCsUYj0nu0YffEkpHZ3tw1t"
client = WebClient(token=slack_token)

try:
    response = client.chat_postMessage(
        channel="U0320SLRKRS",
        text="Hello from your app! :tada:"
    )
except SlackApiError as e:
    # You will get a SlackApiError if "ok" is False
    assert e.response["error"]
# Out:
# DEBUG:slack_sdk.web.base_client:Sending a request - url: https://www.slack.com/api/chat.postMessage, query_params: {}, body_params: {}, files: {}, json_body: {'channel': 'U0320SLRKRS', 'text': 'Hello from your app! :tada:'}, headers: {'Content-Type': 'application/json;charset=utf-8', 'Authorization': '(redacted)', 'User-Agent': 'Python/3.10.2 slackclient/3.15.2 Windows/10'}
# DEBUG:slack_sdk.web.base_client:Received the following response - status: 200, headers: {'date': 'Fri, 13 May 2022 14:36:14 GMT', 'server': 'Apache', 'x-powered-by': 'HHVM/4.153.1', 'access-control-allow-origin': '*', 'referrer-policy': 'no-referrer', 'x-slack-backend': 'r', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'access-control-allow-headers': 'slack-route, x-slack-version-ts, x-b3-traceid, x-b3-spanid, x-b3-parentspanid, x-b3-sampled, x-b3-flags', 'access-control-expose-headers': 'x-slack-req-id, retry-after', 'x-oauth-scopes': 'incoming-webhook,calls:read,chat:write,chat:write.customize,channels:join', 'x-accepted-oauth-scopes': 'chat:write', 'expires': 'Mon, 26 Jul 1997 05:00:00 GMT', 'cache-control': 'private, no-cache, no-store, must-revalidate', 'pragma': 'no-cache', 'x-xss-protection': '0', 'x-content-type-options': 'nosniff', 'x-slack-req-id': 'f754336a5919c0b7fc0f5fa7f7a89675', 'vary': 'Accept-Encoding', 'content-type': 'application/json; charset=utf-8', 'x-envoy-upstream-service-time': '289', 'x-backend': 'main_normal main_bedrock_normal_with_overflow main_canary_with_overflow main_bedrock_canary_with_overflow main_control_with_overflow main_bedrock_control_with_overflow', 'x-server': 'slack-www-hhvm-main-iad-o2is', 'x-slack-shared-secret-outcome': 'no-match', 'via': 'envoy-www-iad-jijl, envoy-edge-bom-cgpd', 'x-edge-backend': 'envoy-www', 'x-slack-edge-shared-secret-outcome': 'no-match', 'connection': 'close', 'transfer-encoding': 'chunked'}, body: {"ok":true,"channel":"D03AHR8NSH4","ts":"1652452574.249699","message":{"bot_id":"B03AMHMFZ0V","type":"message","text":"Hello from your app! :tada:","user":"U03B32LUCRF","ts":"1652452574.249699","app_id":"A03AMH7HVRT","team":"TRY2XHQSJ","bot_profile":{"id":"B03AMHMFZ0V","app_id":"A03AMH7HVRT","name":"Instructor Late DM","icons":{"image_36":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/bot_36.png","image_48":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/bot_48.png","image_72":"https:\/\/a.slack-edge.com\/80588\/img\/plugins\/app\/service_72.png"},"deleted":false,"updated":1649416086,"team_id":"TRY2XHQSJ"},"blocks":[{"type":"rich_text","block_id":"5tNjn","elements":[{"type":"rich_text_section","elements":[{"type":"text","text":"Hello from your app! "},{"type":"emoji","name":"tada"}]}]}]}}
